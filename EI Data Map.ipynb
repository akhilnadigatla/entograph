# %%
import numpy as np
import pandas as pd

df = pd.read_csv('table-sridhar.csv')

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
world_map = gpd.read_file('World_Countries__Generalized_.shp')

# %%
crs = {'init': 'epsg:4326'}
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
geo_df = gpd.GeoDataFrame(df, crs = crs, geometry = geometry)
# Out:
# /Users/akhil/opt/anaconda3/lib/python3.7/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
fig, ax = plt.subplots(figsize = (20, 20))
world_map.plot(ax = ax, alpha = 0.4, color = 'grey', edgecolor = 'black')
geo_df.plot(column = 'EI',ax = ax, alpha = 0.5, legend = True, legend_kwds = {'shrink': 0.6, 'label': 'EI'},
            markersize = 0.1)
plt.title('EI Data Map', fontsize = 15, fontweight = 'bold')
plt.xlim(-150, 150)
plt.ylim(-100, 100)
plt.savefig('ei_data.png', dpi = 1000)
plt.show()
